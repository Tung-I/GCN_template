# %%
import numpy as np
import logging
import nibabel as nib
import math
import matplotlib.pyplot as plt
from numpy import linalg as LA
from skimage.segmentation import slic
from pathlib import Path
from skimage.segmentation import slic
from skimage.segmentation import mark_boundaries
from tqdm import tqdm_notebook as tqdm

# %%
def max_min_normalize(img):
    img = np.asarray(img)
    return (img-np.min(img)) / ((np.max(img)-np.min(img) + 1e-10))

def label_reconstruct(label, segments):
#     label_recon = np.zeros((label.shape[0], label.shape[1]))
    label_recon = np.zeros_like(label)
    id_list = list(np.unique(segments))
    for i in id_list:
        label_recon[np.where(segments==i)] = int(np.median(label[np.where(segments==i)].flatten()))
    return label_recon

# %%
path = Path('/home/tony/Documents/kits19/data/case_00040/')
image = nib.load(str(path / 'imaging.nii.gz')).get_data().astype(np.float32) 
label = nib.load(str(path / 'segmentation.nii.gz')).get_data().astype(np.int64)

# %%
image.shape
# Out:
# (207, 512, 512)

# %%
N_SEG = 512*20
COMPACTNESS = 0.1
image = max_min_normalize(image)
segments = slic(image.astype('double'), n_segments=N_SEG, compactness=COMPACTNESS, multichannel=False)

# %%
n_slice = 70
img_slice = image[n_slice]
label_slice = label[n_slice]
segments_slice = segments[n_slice]
plt.imshow(label_slice)

# %%
plt.imshow(mark_boundaries(img_slice, segments_slice))

# %%
recon = label_reconstruct(label_slice, segments_slice)
plt.imshow(recon)

# %%
image = np.load('/home/tony/Documents/gcn_preprocess/kits19_3d/case_00078/image.npy')
label = np.load('/home/tony/Documents/gcn_preprocess/kits19_3d/case_00078/label.npy')
clf = np.load('/home/tony/Documents/gcn_preprocess/kits19_3d/case_00078/clf_label.npy')
image = max_min_normalize(image)

# %%
n_slice = 3
img_slice = image[:, :, n_slice]
label_slice = label[:, :, n_slice]
plt.subplot(1, 2, 1)
plt.imshow(img_slice)
plt.subplot(1, 2, 2)
plt.imshow(label_slice)

# %%
N_SEG = 2048
COMPACTNESS = 0.1
segments = slic(image.astype('double'), n_segments=N_SEG, compactness=COMPACTNESS, multichannel=False)

# %%
segments_slice = segments[:, :, n_slice]
recon = label_reconstruct(label_slice, segments_slice)
plt.imshow(recon)

# %%
features = feature_extract(image, segments, 2048, 64)
# Out:
# HBox(children=(IntProgress(value=0, max=6498), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5776), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5054), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6156), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4788), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6156), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4788), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6156), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4788), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6156), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4788), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5858), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5691), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4788), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5191), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5814), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5130), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5814), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5316), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5130), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5785), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5330), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5111), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5675), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5185), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5255), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5814), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5130), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5814), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5130), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5814), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5130), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5814), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5130), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5814), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5130), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5814), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5130), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5814), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5130), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5814), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5130), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5814), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5132), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5456), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5415), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4966), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5811), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5468), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5130), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5814), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5191), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5130), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5850), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5699), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4788), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6156), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4788), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6498), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5776), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5054), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6498), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5776), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5054), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6840), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6080), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5320), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=7182), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6384), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5586), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5256), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5448), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5340), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5537), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5326), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4879), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5452), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5778), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5203), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5511), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5188), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5453), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5256), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6156), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4788), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5832), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5184), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4536), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5832), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5184), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4536), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5832), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5184), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4536), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5832), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5184), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4536), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5508), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4860), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5508), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4878), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5508), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4860), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5379), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5022), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5508), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5184), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4860), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5519), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5468), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4860), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5508), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5130), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5508), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5184), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4860), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5508), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5401), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4860), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5508), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5453), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4860), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5796), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5184), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4860), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5508), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5184), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4860), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5508), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5184), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4860), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5148), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4860), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5508), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4878), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5508), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4860), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5508), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5184), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4860), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6155), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4788), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6156), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5472), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4788), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6480), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5760), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5040), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6804), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6048), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5292), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5190), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5185), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5247), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-b7884b4c33aa> in <module>
# ----> 1 features = feature_extract(image, segments, 2048, 64)
#
# <ipython-input-63-bcdbf2d5a683> in feature_extract(img, segments, v_num, f_num)
#      22     features = np.zeros((v_num, f_num))
#      23     for i in range(v_num):
# ---> 24         area = img[np.where(segments==i)]
#      25         features[i] = value_count(area, f_num)
#      26     return features
#
# KeyboardInterrupt:

# %%
def max_min_normalize(img):
    img = np.asarray(img)
    return (img-np.min(img)) / ((np.max(img)-np.min(img) + 1e-10))


def value_count(arr, num):
    """
    Args:
        arr: value 0~1 (numpy.ndarray)
    Returns:
        arr of value count: (numpy.ndarray)
    """
    arr = arr.flatten()
    arr = (arr * (num-1)).astype(np.int32)
    cnt_arr = np.zeros(num).astype(np.int32)
    for i in range(arr.shape[0]):
        cnt_arr[arr[i]] += 1
    return cnt_arr / (cnt_arr.max() + 1e-10)


def feature_extract(img, segments, v_num, f_num):
    features = np.zeros((v_num, f_num))
    for i in tqdm(range(v_num)):
        area = img[np.where(segments==i)]
        features[i] = value_count(area, f_num)
    return features 


def adj_generate(features, segments, tao):
    centroid = []
    range_num = np.minimum(features.shape[0], (segments.max()+1))
#     for i in range(range_num):
#         centroid.append((np.where(segments==i)[0].mean(), np.where(segments==i)[1].mean()))
#     centroid = np.asarray(centroid)
    adj_arr = np.zeros((features.shape[0], features.shape[0]))
    for i in range(range_num):
        for j in range(i+1, range_num):
#             if LA.norm(centroid[i] - centroid[j]) > (segments.shape[0]*threshold):
#                 adj_arr[i, j] = 0
#             else:
#                 e_dist = LA.norm((features[i] - features[j]))
#                 tmp = -1 * e_dist * e_dist / (2*tao*tao)
#                 adj_arr[i, j] = math.exp(tmp)
            e_dist = LA.norm((features[i] - features[j]))
            tmp = -1 * e_dist * e_dist / (2*tao*tao)
            adj_arr[i, j] = math.exp(tmp)
            adj_arr[j, i] = adj_arr[i, j]
    adj_arr += np.eye(features.shape[0])
    return adj_arr


def label_transform(label, segments, v_num, f_num):
    gcn_label = np.zeros((v_num, 1))
    n_range = int(np.minimum(v_num, segments.max()+1))
    for i in range(n_range):
        gcn_label[i] = int(np.median(label[np.where(segments==i)]))
    return gcn_label

def label_reconstruct_3d(label, segments):
    label_recon = np.zeros((label.shape[0], label.shape[1], label.shape[2]))
    id_list = list(np.unique(segments))
    for i in id_list:
        label_recon[np.where(segments==i)] = int(np.median(label[np.where(segments==i)].flatten()))
    return label_recon

def label_reconstruct(label, segments):
#     label_recon = np.zeros((label.shape[0], label.shape[1]))
    label_recon = np.zeros_like(label)
    id_list = list(np.unique(segments))
    for i in id_list:
        label_recon[np.where(segments==i)] = int(np.median(label[np.where(segments==i)].flatten()))
    return label_recon

# %%
# Out:
# 0.7942583732057417
